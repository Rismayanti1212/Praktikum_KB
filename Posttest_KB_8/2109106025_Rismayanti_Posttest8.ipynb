# %% [markdown]
# # POSTTEST 8 PRAKTIKUM KECERDASAN BUATAN
# ### NAMA  : RISMAYANTI
# ### NIM    : 2109106025
# ### KELAS : A1-21

# %% [markdown]
# ## Mengimport Library

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt

# %% [markdown]
# ## Klasifikasi dengan Dataset Tensorflow (rock_paper_scissors)

# %%
(x_train_raw, y_train_raw),(x_test_raw, y_test_raw) = tfds.load("rock_paper_scissors", batch_size=-1, split=['train+test', 'train[:70%]+test'], as_supervised=True)

# %% [markdown]
# ## Menampilkan Gambar Dataset

# %%
for i in range(16):
    plt.subplot(4,4,i+1)
    plt.imshow(x_train_raw[i])
    plt.axis('off')
plt.show()

# %% [markdown]
# # Encoding Label pada Gambar dengan 3 Class

# %%
num_class = 3
y_train= tf.keras.utils.to_categorical(y_train_raw, num_class)
y_test = tf.keras.utils.to_categorical(y_test_raw, num_class)

# %% [markdown]
# ## Menampilkan Shape Dataset

# %%
x_train_raw.shape
# Out:
# TensorShape([2892, 300, 300, 3])

# %%
x_test_raw.shape
# Out:
# TensorShape([2136, 300, 300, 3])

# %% [markdown]
# ## Konversi 28x28 Jadi sebuah vektor berukuran 2352x1
# ### Gambar pada dataset ditentukan pikselnya menjadi 28x28

# %%
training = tf.image.resize(x_train_raw, (28, 28))
testing = tf.image.resize(x_test_raw, (28, 28))

# %% [markdown]
# ### Menentukan jumlah dimensi training dan testing 2D

# %%
training = np.reshape(training.numpy(), (2892, 2352))
testing = np.reshape(testing.numpy(), (2136, 2352))

# %%
training = training.astype('float32')/255

# %%
testing = testing.astype('float32')/255

# %% [markdown]
# ## Membuat Model DNN (DEEP NEURAL NETWORK)
# ### Terdiri dari 3 layer dan 2 aktivasi RELU

# %%
model = Sequential([
        Dense(512, activation = 'relu', input_dim = (2352)),
        Dense(256, activation = 'relu'),
        Dense(3, activation = 'softmax')
    ])

# %% [markdown]
# ## Menampilkan Summary Model

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 512)               1204736
#
#  dense_7 (Dense)             (None, 256)               131328
#
#  dense_8 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 1,336,835
# Trainable params: 1,336,835
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##  Optimalisasi Model

# %% [markdown]
# #### Optimizer yang dipilih sqd
# #### Losss categorical_crossentropy karena data lebih dari 2
# #### metrics accuracyy

# %%
model.compile(optimizer = 'sgd', 
              loss = 'categorical_crossentropy', 
              metrics=['accuracy'])

# %% [markdown]
# ## Training pada Model dengan batch size 64 dan sebanyak epoch 30

# %%
hist = model.fit(training, y_train, batch_size=64, epochs=30, validation_data=(testing, y_test))
# Out:
# Epoch 1/30
# 46/46 [==============================] - 1s 14ms/step - loss: 1.1358 - accuracy: 0.4602 - val_loss: 1.7155 - val_accuracy: 0.3305
# Epoch 2/30
# 46/46 [==============================] - 0s 10ms/step - loss: 0.9627 - accuracy: 0.5474 - val_loss: 0.9907 - val_accuracy: 0.4054
# Epoch 3/30
# 46/46 [==============================] - 1s 12ms/step - loss: 0.8836 - accuracy: 0.5858 - val_loss: 0.9437 - val_accuracy: 0.4565
# Epoch 4/30
# 46/46 [==============================] - 1s 12ms/step - loss: 0.8071 - accuracy: 0.6470 - val_loss: 1.2507 - val_accuracy: 0.4148
# Epoch 5/30
# 46/46 [==============================] - 1s 13ms/step - loss: 0.7688 - accuracy: 0.6791 - val_loss: 0.8276 - val_accuracy: 0.6400
# Epoch 6/30
# 46/46 [==============================] - 1s 12ms/step - loss: 0.7081 - accuracy: 0.7064 - val_loss: 1.2837 - val_accuracy: 0.4082
# Epoch 7/30
# 46/46 [==============================] - 1s 11ms/step - loss: 0.6517 - accuracy: 0.7559 - val_loss: 1.0270 - val_accuracy: 0.5290
# Epoch 8/30
# 46/46 [==============================] - 1s 12ms/step - loss: 0.6647 - accuracy: 0.7296 - val_loss: 0.5516 - val_accuracy: 0.8230
# Epoch 9/30
# 46/46 [==============================] - 1s 12ms/step - loss: 0.6032 - accuracy: 0.7535 - val_loss: 0.7231 - val_accuracy: 0.6606
# Epoch 10/30
# 46/46 [==============================] - 1s 12ms/step - loss: 0.5867 - accuracy: 0.7555 - val_loss: 0.8259 - val_accuracy: 0.6184
# Epoch 11/30
# 46/46 [==============================] - 1s 11ms/step - loss: 0.5508 - accuracy: 0.7911 - val_loss: 1.2055 - val_accuracy: 0.4565
# Epoch 12/30
# 46/46 [==============================] - 1s 12ms/step - loss: 0.4910 - accuracy: 0.8167 - val_loss: 0.4426 - val_accuracy: 0.8525
# Epoch 13/30
# 46/46 [==============================] - 1s 11ms/step - loss: 0.4943 - accuracy: 0.8039 - val_loss: 0.5052 - val_accuracy: 0.7711
# Epoch 14/30
# 46/46 [==============================] - 1s 11ms/step - loss: 0.4387 - accuracy: 0.8416 - val_loss: 0.3873 - val_accuracy: 0.8801
# Epoch 15/30
# 46/46 [==============================] - 0s 10ms/step - loss: 0.4160 - accuracy: 0.8423 - val_loss: 0.4574 - val_accuracy: 0.8193
# Epoch 16/30
# 46/46 [==============================] - 1s 11ms/step - loss: 0.3738 - accuracy: 0.8658 - val_loss: 0.3448 - val_accuracy: 0.9003
# Epoch 17/30
# 46/46 [==============================] - 1s 11ms/step - loss: 0.3351 - accuracy: 0.8918 - val_loss: 0.2742 - val_accuracy: 0.9101
# Epoch 18/30
# 46/46 [==============================] - 1s 15ms/step - loss: 0.3527 - accuracy: 0.8786 - val_loss: 2.2102 - val_accuracy: 0.3731
# Epoch 19/30
# 46/46 [==============================] - 1s 13ms/step - loss: 0.4221 - accuracy: 0.8586 - val_loss: 0.8866 - val_accuracy: 0.5342
# Epoch 20/30
# 46/46 [==============================] - 0s 10ms/step - loss: 0.2570 - accuracy: 0.9257 - val_loss: 0.2044 - val_accuracy: 0.9419
# Epoch 21/30
# 46/46 [==============================] - 0s 11ms/step - loss: 0.2821 - accuracy: 0.9039 - val_loss: 0.2347 - val_accuracy: 0.9251
# Epoch 22/30
# 46/46 [==============================] - 1s 11ms/step - loss: 0.2052 - accuracy: 0.9398 - val_loss: 0.3834 - val_accuracy: 0.8202
# Epoch 23/30
# 46/46 [==============================] - 0s 10ms/step - loss: 0.3079 - accuracy: 0.9015 - val_loss: 0.2047 - val_accuracy: 0.9312
# Epoch 24/30
# 46/46 [==============================] - 0s 10ms/step - loss: 0.2018 - accuracy: 0.9433 - val_loss: 0.2037 - val_accuracy: 0.9298
# Epoch 25/30
# 46/46 [==============================] - 1s 11ms/step - loss: 0.2094 - accuracy: 0.9281 - val_loss: 1.9866 - val_accuracy: 0.4153
# Epoch 26/30
# 46/46 [==============================] - 0s 11ms/step - loss: 0.3088 - accuracy: 0.9001 - val_loss: 0.7214 - val_accuracy: 0.6723
# Epoch 27/30
# 46/46 [==============================] - 0s 10ms/step - loss: 0.2416 - accuracy: 0.9163 - val_loss: 0.9286 - val_accuracy: 0.7697
# Epoch 28/30
# 46/46 [==============================] - 0s 10ms/step - loss: 0.2742 - accuracy: 0.9094 - val_loss: 0.4319 - val_accuracy: 0.8109
# Epoch 29/30
# 46/46 [==============================] - 0s 10ms/step - loss: 0.1473 - accuracy: 0.9585 - val_loss: 0.1626 - val_accuracy: 0.9462
# Epoch 30/30
# 46/46 [==============================] - 0s 11ms/step - loss: 0.1736 - accuracy: 0.9506 - val_loss: 0.2143 - val_accuracy: 0.9176

# %% [markdown]
# ## Evaluasi Data setelah Training
# #### Accuracy dan Validasi menunjukkan hasil yang cocok tidak overfitting/ underfitting

# %%
score = model.evaluate(testing, y_test)
print("TEST LOSS           : ", score [0])
print("TEST ACCURACY       : ", score [1])
print("VALIDATION LOSS     : ", hist.history['val_loss'][-1])
print("VALIDATION ACCURACY : ", hist.history['val_accuracy'][-1])
# Out:
# 67/67 [==============================] - 0s 4ms/step - loss: 0.2143 - accuracy: 0.9176
# TEST LOSS           :  0.21425184607505798
# TEST ACCURACY       :  0.9176030158996582
# VALIDATION LOSS     :  0.21425184607505798
# VALIDATION ACCURACY :  0.9176030158996582

# %% [markdown]
# ## Perbandingan Loss dan Validasi Loss

# %%
plt.style.use('ggplot')
plt.plot(hist.history['loss'], label = 'loss')
plt.plot(hist.history['val_loss'], label='val loss')
plt.title("Perbandingan Loss dan Validasi Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# ## Perbandingan Accuracy dan Vlidasi Accuracy

# %%
plt.plot(hist.history['accuracy'], label = 'accuracy')
plt.plot(hist.history['val_accuracy'], label='val_accuracy')
plt.title("Perbandingan Accuracy dan Validasi Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
